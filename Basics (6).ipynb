# %%
from csv import reader

with open("AppleStore.csv") as data:
    read_data = reader(data)
    Apple_data = list(read_data)
    Apple_header = Apple_data[0]
    Apple_main = Apple_data[1:]

with open("googleplaystore.csv") as google:
    reading = reader(google)
    google_data = list(reading)
    google_header = google_data[0]
    google_main = google_data[1:]

# %%
def explore_dataset(dataset,start,end,rows_and_columns = False):
    data_slice = dataset[start:end]
    for each_row in data_slice:
        print(each_row)
        print('\n')
    if rows_and_columns:
        print("The number of columns is:",len(dataset[0]))
        print("Then number of row is:",len(dataset))

# %%
print(google_header)
print('\n')
print(google_main[:5])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ...

# %%
print(Apple_header)
print('\n')
print(Apple_main[:10])
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ...

# %%
exploring_1 = explore_dataset(Apple_data,0,5,True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# The number of columns is: 16
# Then number of row is: 7198

# %%
exploring_2 = explore_dataset(google_data,0,5,True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# The number of columns is: 13
# Then number of row is: 10842

# %%
print(google_header)
print('\n')
print(google_main[10472:10475])
print('\n')
print(google_main[0])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# [['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up'], ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up'], ['Sat-Fi Voice', 'COMMUNICATION', '3.4', '37', '14M', '1,000+', 'Free', '0', 'Everyone', 'Communication', 'November 21, 2014', '2.2.1.5', '2.2 and up']]
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']

# %%
print(google_main[10472][8])
print(google_header[8])
# Out:
# Content Rating

# %% [markdown]
# # The data in this row number 10472 of Google_main has an error and thus,I will remove.

# %%
del google_main[10472]

# %%
print(google_main[10472])
# Out:
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']

# %%
duplicate_apps = []
unique_apps = []
for each in google_data:
    app_name = each[0]
    if app_name in unique_apps:
        duplicate_apps.append(app_name)
    unique_apps.append(app_name)
print(len(unique_apps))
print('\n')
print(len(duplicate_apps))
print('\n')
print(duplicate_apps[1:15])
# Out:
# 10842
#
#
# 1181
#
#
# ['Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %%
for app in google_data:
    name = app[0]
    if name == "Instagram" or name == "Facebook":
        print(app)
        print('\n')
# Out:
# ['Facebook', 'SOCIAL', '4.1', '78158306', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'August 3, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ...

# %%
app_names = []
for each in google_data:
    name =each[0]
    app_names.append(name)

# %%
print(app_names[:10])
# Out:
# ['App', 'Photo Editor & Candy Camera & Grid & ScrapBook', 'Coloring book moana', 'U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'Sketch - Draw & Paint', 'Pixel Draw - Number Art Coloring Book', 'Paper flowers instructions', 'Smoke Effect Photo Maker - Smoke Editor', 'Infinite Painter', 'Garden Coloring Book']

# %%
app_freq = {}
for each in app_names:
    if each in app_freq:
        app_freq[each] +=1
    else:
        app_freq[each] = 1
print(app_freq)
# Out:
# {'Ruler cm': 1, 'EH National Mobile Banking': 1, 'IndiaMART: Search Products, Buy, Sell & Trade': 1, 'Ideal Weight, BMI Calculator': 1, 'Dr. Parking 4': 1, 'St. Petersburg, FL - weather and more': 1, 'Cardboard': 2, 'FG Finder': 1, 'TheFork - Restaurants booking and special offers': 1, 'BG LINKED (BGLINKED)': 1, 'FD Fitness': 1, 'How do I take care of my child?': 1, 'Klix.ba': 1, 'Last Shelter: Survival': 1, 'E*TRADE Mobile': 2, 'All C Programs': 1, 'Mini for fb lite': 1, 'Platincoin Wallet - PLC Group AG': 1, 'Lie Detector Prank': 1, 'Planet O - Icon Pack': 1, 'Dulquer Salmaan HD Wallpapers': 1, 'BROTHER IN WARS: GUNNER CITY WARLORDS': 1, 'Glide - Video Chat Messenger': 2, 'Learn to Speak English': 1, 'Lamp detector': 1, 'ES File Explorer & Manager, Locker Xplorer 2018': 1, 'I am Nose Doctor -Save my Nose': 1, 'Monster Ride Pro': 1, 'Foot Surgery Hospital Simulator: ER Doctor Games': 1, 'Mobile C [ C/C++ Compiler ]': 1, 'lesparticuliers.fr': 1, 'BT Communicator': 1, 'TickTick: To Do
# ...

# %%
for each in app_freq:
    if app_freq[each] >=2:
        print(each)
        print('\n')
# Out:
# Cardboard
#
#
# E*TRADE Mobile
#
#
# Glide - Video Chat Messenger
#
#
# TickTick: To Do List with Reminder, Day Planner
#
#
# Solitaire
#
#
# Game for KIDS: KIDS match'em
#
#
# Angry Birds Classic
#
#
# DRAGON BALL LEGENDS
#
#
# MARVEL Strike Force
#
#
# Medical ID - In Case of Emergency (ICE)
#
#
# Block Craft 3D: Building Simulator Games For Free
#
#
# Google News
#
#
# FreshBooks Classic
#
#
# HBO NOW: Stream TV & Movies
#
#
# Home Workout - No Equipment
#
#
# Wunderlist: To-Do List & Tasks
#
#
# Hungry Shark Evolution
#
#
# Spanish English Translator
#
#
# AliExpress - Smarter Shopping, Better Living
#
#
# MouseMingle
#
#
# RT 516 VET
#
#
# Cheapflights – Flight Search
#
#
# We Heart It
#
#
# Food Calorie Calculator
#
#
# Microsoft PowerPoint
#
#
# Shopkins World!
#
#
# Yandex Browser with Protect
#
#
# CBS - Full Episodes & Live TV
#
#
# HD Camera for Android
#
#
# Tubi TV - Free Movies & TV
#
#
# Google Sheets
#
#
# Wanelo Shopping
#
#
# Text free - Free Text + Call
#
#
# ...

# %% [markdown]
# #As shown above the Google data has 1811 duplicated data that need to be removed.

# %%
reviews_max = {}

for app in google_main:
    name = app[0]
    n_reviews = float(app[3])
    
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
        
    elif name not in reviews_max:
        reviews_max[name] = n_reviews

# %%
print('Expected length:', len(google_main) - 1181)
print('Actual length:', len(review_max))
# Out:
# Expected length: 9659
# Actual length: 0
